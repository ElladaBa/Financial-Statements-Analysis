# %% [markdown]
# # GET DATA

# %%
import requests
import urllib
from bs4 import BeautifulSoup

import json
import pandas as pd

import matplotlib.pyplot as plt

from datetime import date
today = date.today()

# %%
# //- // Company Specific code

### Set variables for company to scrape data for company of interest
# to identify cik and proper name for company,
# search at https://www.sec.gov/edgar/searchedgar/cik.htm

# to identify component of link to 10k (annual reports), 
# search folders at https://www.sec.gov/Archives/edgar/data/cik
# where cik shall be replaced by cik of company under analysis

############ Set variables for company of interest ##
company = 'Tesla, Inc.'                             #
cik = '1318605'                                     #
link_to_10k = '/000156459021004599/'                # 
#####################################################

# %%
### Scraping data from SEC EDGAR 

# google for headers for your browser
headers = {'User-Agent': 'your headers go here'}
# be nice to host servers, set timeout
timeout = 3

# first part of url to scrape from - same for all companies
base_url = "https://www.sec.gov/Archives/edgar/data/"

# unique to company url with link to 10-K filling
doc_url = base_url + cik + link_to_10k + 'index.json'

# financial (10-K/ 10-Q) reports contained in FilingSummary.xml 
# write function to extract this summary from url
def get_xml_summary(url):
    
    # required to construct url to xml_summary
    home_url = r"https://www.sec.gov" 
    
    # get url content and as json file 
    content = requests.get(url, headers=headers, timeout=timeout).json()
    
    # content result is nested dictionary
    # print(content)
    for file in content['directory']['item']:
        if file['name']=='FilingSummary.xml':
            xml_summary = home_url + content['directory']['name'] + '/' + file['name']
    return xml_summary

# now apply function to extract xml_summary from url
xml_summary = get_xml_summary(doc_url)

# reports in xml_summary are stored under tag name 'myreports'
# let's get to them by parsing xml_summary 
# write function to parse xml and extract list of reports
def get_reports(xml_summary):
    
    content = requests.get(xml_summary, headers=headers, timeout=timeout).content
    soup = BeautifulSoup(content, 'lxml')
    reports = soup.find('myreports')
    #print(reports)    
    
    # store parsed reports in reports list
    fin_reports = []
   
    # each report contains several elements
    # create dictionary to store elements
    for report in reports.find_all('report')[:-1]: # last report is incomplete and causes error
        report_dict = {}
        report_dict['long_name'] = report.longname.text
        report_dict['short_name'] = report.shortname.text
        report_dict['category'] = report.menucategory.text
        report_dict['position'] = report.position.text
        report_dict['url'] = xml_summary.replace('FilingSummary.xml', '') + report.htmlfilename.text
        #print(report_dict)   
        
        # append to list of reports
        fin_reports.append(report_dict)
    return fin_reports

# apply function to extract list of reports for the company
reports_list = get_reports(xml_summary)

# print list of reports
print('-'*100)
print(f'The following statements are available from 10-K fillings by {company}')
print('')
for i in range(len(reports_list)):
    print(f"Statement position: {reports_list[i]['position']}\n{reports_list[i]['short_name']}\n{reports_list[i]['url']}")
    print('')
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# The following statements are available from 10-K fillings by Tesla, Inc.
#
# Statement position: 1
# Document and Entity Information
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R1.htm
#
# Statement position: 2
# Consolidated Balance Sheets
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R2.htm
#
# Statement position: 3
# Consolidated Balance Sheets (Parenthetical)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R3.htm
#
# Statement position: 4
# Consolidated Statements of Operations
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R4.htm
#
# Statement position: 5
# Consolidated Statements of Operations (Parenthetical)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R5.htm
#
# Statement position: 6
# Consolidated Statements of Comprehensive Income (Loss)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R6.htm
#
# Statement position: 7
# Consolidated Statements of Redeemable Noncontrolling Interest and Stockholders' Equity
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R7.htm
#
# Statement position: 8
# Consolidated Statements of Redeemable Noncontrolling Interest and Stockholders' Equity (Parenthetical)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R8.htm
#
# Statement position: 9
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R9.htm
#
# Statement position: 10
# Overview
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R10.htm
#
# Statement position: 11
# Summary of Significant Accounting Policies
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R11.htm
#
# Statement position: 12
# Business Combinations
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R12.htm
#
# Statement position: 13
# Goodwill and Intangible Assets
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R13.htm
#
# Statement position: 14
# Fair Value of Financial Instruments
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R14.htm
#
# Statement position: 15
# Inventory
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R15.htm
#
# Statement position: 16
# Solar Energy Systems, Net
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R16.htm
#
# Statement position: 17
# Property, Plant and Equipment, Net
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R17.htm
#
# Statement position: 18
# Accrued Liabilities and Other
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R18.htm
#
# Statement position: 19
# Other Long-Term Liabilities
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R19.htm
#
# Statement position: 20
# Customer Deposits
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R20.htm
#
# Statement position: 21
# Debt
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R21.htm
#
# Statement position: 22
# Leases
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R22.htm
#
# Statement position: 23
# Equity Incentive Plans
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R23.htm
#
# Statement position: 24
# Income Taxes
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R24.htm
#
# Statement position: 25
# Commitments and Contingencies
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R25.htm
#
# Statement position: 26
# Variable Interest Entity Arrangements
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R26.htm
#
# Statement position: 27
# Lease Pass-Through Financing Obligation
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R27.htm
#
# Statement position: 28
# Defined Contribution Plan
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R28.htm
#
# Statement position: 29
# Related Party Transactions
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R29.htm
#
# Statement position: 30
# Segment Reporting and Information about Geographic Areas
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R30.htm
#
# Statement position: 31
# Restructuring and Other
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R31.htm
#
# Statement position: 32
# Subsequent Events
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R32.htm
#
# Statement position: 33
# Quarterly Results of Operations
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R33.htm
#
# Statement position: 34
# Summary of Significant Accounting Policies (Policies)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R34.htm
#
# Statement position: 35
# Summary of Significant Accounting Policies (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R35.htm
#
# Statement position: 36
# Business Combinations (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R36.htm
#
# Statement position: 37
# Goodwill and Intangible Assets (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R37.htm
#
# Statement position: 38
# Fair Value of Financial Instruments (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R38.htm
#
# Statement position: 39
# Inventory (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R39.htm
#
# Statement position: 40
# Solar Energy Systems, Net (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R40.htm
#
# Statement position: 41
# Property, Plant and Equipment, Net (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R41.htm
#
# Statement position: 42
# Accrued Liabilities and Other (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R42.htm
#
# Statement position: 43
# Other Long-Term Liabilities (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R43.htm
#
# Statement position: 44
# Debt (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R44.htm
#
# Statement position: 45
# Leases (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R45.htm
#
# Statement position: 46
# Equity Incentive Plans (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R46.htm
#
# Statement position: 47
# Income Taxes (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R47.htm
#
# Statement position: 48
# Variable Interest Entity Arrangements (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R48.htm
#
# Statement position: 49
# Lease Pass-Through Financing Obligation (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R49.htm
#
# Statement position: 50
# Segment Reporting and Information about Geographic Areas (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R50.htm
#
# Statement position: 51
# Quarterly Results of Operations (Tables)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R51.htm
#
# Statement position: 52
# Overview - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R52.htm
#
# Statement position: 53
# Summary of Significant Accounting Policies - Schedule of Disaggregation of Revenue by Major Source (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R53.htm
#
# Statement position: 54
# Summary of Significant Accounting Policies - Schedule of Disaggregation of Revenue by Major Source (Parenthetical) (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R54.htm
#
# Statement position: 55
# Summary of Significant Accounting Policies - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R55.htm
#
# Statement position: 56
# Summary of Significant Accounting Policies - Schedule of Deferred Revenue Activity (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R56.htm
#
# Statement position: 57
# Summary of Significant Accounting Policies - Additional Information (Detail1)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R57.htm
#
# Statement position: 58
# Summary of Significant Accounting Policies - Schedule of Reconciliation of Basic to Diluted Weighted Average Shares Used in Computing Net Income (Loss) Per Share of Common Stock, as Adjusted to Give Effect to Stock Split (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R58.htm
#
# Statement position: 59
# Summary of Significant Accounting Policies - Schedule of Potentially Dilutive Shares that were Excluded from Computation of Diluted Net Income (Loss) per Share of Common Stock (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R59.htm
#
# Statement position: 60
# Summary of Significant Accounting Policies - Schedule of Cash and Cash Equivalents and Restricted Cash (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R60.htm
#
# Statement position: 61
# Summary of Significant Accounting Policies - Estimated Useful Lives of Respective Assets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R61.htm
#
# Statement position: 62
# Summary of Significant Accounting Policies - Schedule of Estimated Useful Lives of Related Assets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R62.htm
#
# Statement position: 63
# Summary of Significant Accounting Policies - Schedule of Accrued Warranty Activity (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R63.htm
#
# Statement position: 64
# Business Combinations - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R64.htm
#
# Statement position: 65
# Business Combinations - Schedule of Fair Values of the Assets Acquired and the Liabilities Assumed (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R65.htm
#
# Statement position: 66
# Business Combinations - Schedule of Fair Value of the Identified Intangible Assets and their Useful Lives (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R66.htm
#
# Statement position: 67
# Goodwill and Intangible Assets - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R67.htm
#
# Statement position: 68
# Goodwill and Intangible Assets - Summary of Acquired Intangible Assets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R68.htm
#
# Statement position: 69
# Goodwill and Intangible Assets - Total Future Amortization Expense for Finite-lived Intangible Assets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R69.htm
#
# Statement position: 70
# Fair Value of Financial Instruments - Schedule of Assets and Liabilities Measured at Fair Value on Recurring Basis (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R70.htm
#
# Statement position: 71
# Fair Value of Financial Instruments - Schedule of Interest Rate Swaps Outstanding (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R71.htm
#
# Statement position: 72
# Fair Value of Financial Instruments - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R72.htm
#
# Statement position: 73
# Fair Value of Financial Instruments - Schedule of Estimated Fair Values and Carrying Values (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R73.htm
#
# Statement position: 74
# Inventory - Schedule of Inventory (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R74.htm
#
# Statement position: 75
# Inventory - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R75.htm
#
# Statement position: 76
# Solar Energy Systems, Net - Components of Solar Energy Systems, Net (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R76.htm
#
# Statement position: 77
# Solar Energy Systems, Net - Components of Solar Energy Systems, Net (Parenthetical) (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R77.htm
#
# Statement position: 78
# Property, Plant and Equipment, Net - Schedule of Property, Plant and Equipment, Net (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R78.htm
#
# Statement position: 79
# Property, Plant and Equipment, Net - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R79.htm
#
# Statement position: 80
# Accrued Liabilities and Other - Schedule of Accrued Liabilities and Other Current Liabilities (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R80.htm
#
# Statement position: 81
# Other Long-Term Liabilities - Schedule of Other Long-term Liabilities (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R81.htm
#
# Statement position: 82
# Debt - Summary of Debt and Finance Lease (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R82.htm
#
# Statement position: 83
# Debt - 2021 Notes, Bond Hedges and Warrant Transactions - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R83.htm
#
# Statement position: 84
# Debt - 2022 Notes, Bond Hedges and Warrant Transactions - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R84.htm
#
# Statement position: 85
# Debt - 2024 Notes, Bond Hedges and Warrant Transactions - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R85.htm
#
# Statement position: 86
# Debt - 2025 Notes - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R86.htm
#
# Statement position: 87
# Debt - Credit Agreement - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R87.htm
#
# Statement position: 88
# Debt - Zero-Coupon Convertible Senior Notes due in 2020 - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R88.htm
#
# Statement position: 89
# Debt - Solar Bonds and other Loans - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R89.htm
#
# Statement position: 90
# Debt - Automotive Asset-backed Notes - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R90.htm
#
# Statement position: 91
# Debt - Solar Asset-backed Notes - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R91.htm
#
# Statement position: 92
# Debt - China Loan Agreements - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R92.htm
#
# Statement position: 93
# Debt - Cash Equity Debt - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R93.htm
#
# Statement position: 94
# Debt - Solar Loan-backed Notes - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R94.htm
#
# Statement position: 95
# Debt - Warehouse Agreement - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R95.htm
#
# Statement position: 96
# Debt - Automotive Lease-backed Credit Facilities - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R96.htm
#
# Statement position: 97
# Debt - Schedule of Interest Expense (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R97.htm
#
# Statement position: 98
# Debt - Pledged Assets - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R98.htm
#
# Statement position: 99
# Debt - Schedule of Future Principal Maturities of Debt (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R99.htm
#
# Statement position: 100
# Leases - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R100.htm
#
# Statement position: 101
# Leases - Schedule of Operating and Financing Leases Presented in Balance Sheets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R101.htm
#
# Statement position: 102
# Leases - Schedule of Components of Lease Expense (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R102.htm
#
# Statement position: 103
# Leases - Schedule of Other Information Related to Leases (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R103.htm
#
# Statement position: 104
# Leases - Supplemental Cash Flow Information related to Leases (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R104.htm
#
# Statement position: 105
# Leases - Schedule of Maturities of Operating and Finance Lease Liabilities (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R105.htm
#
# Statement position: 106
# Leases - Maturities of Operating Lease and Sales-Type Lease Receivables from Customers (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R106.htm
#
# Statement position: 107
# Leases - Schedule of Lease Receivables Relating to Sales-Type Leases (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R107.htm
#
# Statement position: 108
# Equity Incentive Plans - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R108.htm
#
# Statement position: 109
# Equity Incentive Plans - Summary of Stock Option and RSU Activity (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R109.htm
#
# Statement position: 110
# Equity Incentive Plans - Schedule of Fair Value of Stock Option Award and ESPP on Grant Date (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R110.htm
#
# Statement position: 111
# Equity Incentive Plans - Summary of Operational Milestone Based on Revenue or Adjusted EBITDA (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R111.htm
#
# Statement position: 112
# Equity Incentive Plans - Summary of Stock-Based Compensation Expense (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R112.htm
#
# Statement position: 113
# Income Taxes - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R113.htm
#
# Statement position: 114
# Income Taxes - Schedule of Income (Loss) Before Provision for Income Taxes (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R114.htm
#
# Statement position: 115
# Income Taxes - Components of Provision for Income Taxes (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R115.htm
#
# Statement position: 116
# Income Taxes - Schedule of Deferred Tax Assets (Liabilities) (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R116.htm
#
# Statement position: 117
# Income Taxes - Schedule of Reconciliation of Taxes at Federal Statutory Rate to Provision for Income Taxes (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R117.htm
#
# Statement position: 118
# Income Taxes - Schedule of Changes to Gross Unrecognized Tax Benefits (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R118.htm
#
# Statement position: 119
# Commitments and Contingencies - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R119.htm
#
# Statement position: 120
# Variable Interest Entity Arrangements - Carrying Values of Assets and Liabilities of Subsidiary in Consolidated Balance Sheets (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R120.htm
#
# Statement position: 121
# Lease Pass-Through Financing Obligation - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R121.htm
#
# Statement position: 122
# Lease Pass-Through Financing Obligation - Schedule of Future Minimum Lease Payments to be Received for Operating Leases (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R122.htm
#
# Statement position: 123
# Defined Contribution Plan - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R123.htm
#
# Statement position: 124
# Related Party Transactions - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R124.htm
#
# Statement position: 125
# Segment Reporting and Information about Geographic Areas - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R125.htm
#
# Statement position: 126
# Segment Reporting and Information about Geographic Areas - Schedule of Total Revenues and Gross Profit by Reportable Segment (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R126.htm
#
# Statement position: 127
# Segment Reporting and Information about Geographic Areas - Schedule of Revenues by Geographic Area (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R127.htm
#
# Statement position: 128
# Segment Reporting and Information about Geographic Areas - Schedule of Long-Lived Assets by Geographic Area (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R128.htm
#
# Statement position: 129
# Restructuring and Other - Additional Information (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R129.htm
#
# Statement position: 130
# Subsequent Events - Additional Information (Details)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R130.htm
#
# Statement position: 131
# Quarterly Results of Operations - Schedule of Selected Quarterly Results of Operations (Detail)
# https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/R131.htm
#
# ----------------------------------------------------------------------------------------------------

# %%
# next step is to identify statement of interest by its position 
# and parse corresponding table

# write function to parse a table
def parse_table(statement):
    
    # there are 3 parts in table
    # header, sections and data
    # will parse rows considering this difference
    
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] =[]
    statement_data['data'] = []
    
    # get and parse table from statement url
    content = requests.get(statement, headers=headers, timeout=timeout).content
    soup = BeautifulSoup(content, 'html')
    
    #print(soup.table.find_all('tr'))
    
    # find all rows in table
    for index, row in enumerate(soup.table.find_all('tr')):
        #print(index, row)
        
        # elements are contained in 'td' tags
        cols = row.find_all('td')
        
        # header row has 'th' tag
        if (len(row.find_all('th'))!=0):
            header_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(header_row)
            
        # section rows have 'strong' tag
        elif (len(row.find_all('th'))==0 and len(row.find_all('strong'))!=0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
        
        # data rows
        elif (len(row.find_all('th'))==0 and len(row.find_all('strong'))==0):
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
        
        # else is error
        else:
            print('Error when parsing')
        
    return statement_data

# %% [markdown]
# **Parse statements from scraped links**

# %%
### following are key statements, several more can be parsed from reports_list
st_of_financial_position = parse_table(reports_list[1]['url'])
st_of_profit_or_loss = parse_table(reports_list[3]['url'])
st_of_comprehensive_income_loss = parse_table(reports_list[5]['url'])
st_of_changes_in_equity = parse_table(reports_list[6]['url'])
st_of_cash_flows = parse_table(reports_list[8]['url'])

# following tables will require different approch when converting to dataframe
ppe = parse_table(reports_list[16]['url'])
segment_revenues = parse_table(reports_list[126]['url'])

# %% [markdown]
# # PARSE and CLEAN DATA

# %% [markdown]
# **Statement of Financial Position**

# %%
### STATEMENT OF FINANCIAL POSITION ###
### original table can be reviwed by running (reports_list[1]['url'])

st_of_financial_position_df = pd.DataFrame(data = st_of_financial_position['data'])

### drop empty column     
st_of_financial_position_df = st_of_financial_position_df.drop(1, axis=1)

### drop last three rows with None values
st_of_financial_position_df.drop(st_of_financial_position_df.tail(3).index, inplace=True)

### set titles of line items as index
st_of_financial_position_df.index = st_of_financial_position_df[0]
st_of_financial_position_df = st_of_financial_position_df.drop(0, axis=1)
st_of_financial_position_df.index.name = 'Balance Sheet, MLN USD'

### assign column names
st_of_financial_position_df.columns = st_of_financial_position['headers'][0][1:3]

### clean data
st_of_financial_position_df = (st_of_financial_position_df.replace('[\$, ]', '', regex=True)
                               .replace('[(]', '-', regex=True)
                               .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
st_of_financial_position_df = st_of_financial_position_df.astype(float)

# %%
# //- // Company Specific code
#st_of_financial_position_df.to_csv("tesla_bs_2020.csv")

# %% [markdown]
# **Statement of Profit or Loss**

# %%
### STATEMENT OF PROFIT OR LOSS ###
### original table can be reviwed by running (reports_list[3]['url'])

st_of_profit_or_loss_df = pd.DataFrame(data = st_of_profit_or_loss['data'])

### drop empty column     
st_of_profit_or_loss_df = st_of_profit_or_loss_df.drop(1, axis=1)

### drop last three rows with None values
st_of_profit_or_loss_df.drop(st_of_profit_or_loss_df.tail(3).index, inplace=True)

### set titles of line items as index
st_of_profit_or_loss_df.index = st_of_profit_or_loss_df[0]
st_of_profit_or_loss_df = st_of_profit_or_loss_df.drop(0, axis=1)
st_of_profit_or_loss_df.index.name = 'Income Statement, MLN USD'

### assign column names
st_of_profit_or_loss_df.columns = st_of_profit_or_loss['headers'][1]

### clean data
st_of_profit_or_loss_df = (st_of_profit_or_loss_df.replace('[\$, ]', '', regex=True)
                               .replace('[(]', '-', regex=True)
                               .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
st_of_profit_or_loss_df = st_of_profit_or_loss_df.astype(float)

# %%
# //- // Company Specific code
#st_of_profit_or_loss_df.to_csv("tesla_is_2020.csv")

# %% [markdown]
# **Statement of comprehensive income (loss)**

# %%
### COMPREHENSIVE INCOME (LOSS) ###

st_of_comprehensive_income_loss_df = pd.DataFrame(data = st_of_comprehensive_income_loss['data'])


### set titles of line items as index
st_of_comprehensive_income_loss_df.index = st_of_comprehensive_income_loss_df[0]
st_of_comprehensive_income_loss_df = st_of_comprehensive_income_loss_df.drop(0, axis=1)
st_of_comprehensive_income_loss_df.index.name = 'Compr. Income Statement, MLN USD'

### assign column names
st_of_comprehensive_income_loss_df.columns = st_of_comprehensive_income_loss['headers'][1]

### clean data
st_of_comprehensive_income_loss_df = (st_of_comprehensive_income_loss_df.replace('[\$, ]', '', regex=True)
                               .replace('[(]', '-', regex=True)
                               .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
st_of_comprehensive_income_loss_df = st_of_comprehensive_income_loss_df.astype(float)

# %%
# //- // Company Specific code
#st_of_comprehensive_income_loss_df.to_csv("tesla__comp_is_2020.csv")

# %% [markdown]
# **Statement of Cash Flows**

# %%
### STATEMENT OF CASH FLOWS ###

st_of_cash_flows_df = pd.DataFrame(data = st_of_cash_flows['data'])

### set titles of line items as index
st_of_cash_flows_df.index = st_of_cash_flows_df[0]
st_of_cash_flows_df = st_of_cash_flows_df.drop(0, axis=1)
st_of_cash_flows_df.index.name = 'Cash Flows, MLN USD'

### assign column names
st_of_cash_flows_df.columns = st_of_cash_flows['headers'][1]

### clean data
st_of_cash_flows_df = (st_of_cash_flows_df.replace('[\$, ]', '', regex=True)
                               .replace('[(]', '-', regex=True)
                               .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
st_of_cash_flows_df = st_of_cash_flows_df.astype(float)

# %%
# //- // Company Specific code
#st_of_cash_flows_df.to_csv("tesla_cf_2020.csv")

# %% [markdown]
# **Statement of changes in Shareholders' Equity**

# %%
### Statement of changes in shareholders' equity
st_of_changes_in_equity_df = pd.DataFrame(st_of_changes_in_equity['data'])

### drop empty column     
st_of_changes_in_equity_df = st_of_changes_in_equity_df.drop([1, 7, 9], axis=1)

### drop last three rows with None values
st_of_changes_in_equity_df.drop(st_of_changes_in_equity_df.tail(3).index, inplace=True)

### set titles of line items as index
st_of_changes_in_equity_df.index = st_of_changes_in_equity_df[0]
st_of_changes_in_equity_df = st_of_changes_in_equity_df.drop(0, axis=1)
st_of_changes_in_equity_df.index.name = 'Statement of Equity'


### assign column names
hd = st_of_changes_in_equity['headers'][0][1:].copy()
del hd[7]
del hd[8]
del hd[9]
st_of_changes_in_equity_df.columns = hd

### clean data
st_of_changes_in_equity_df = (st_of_changes_in_equity_df.replace('[\$, ]', '', regex=True)
                               .replace('[(]', '-', regex=True)
                               .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
st_of_changes_in_equity_df = st_of_changes_in_equity_df.astype(float)

# %%
# //- // Company Specific code
#st_of_changes_in_equity_df.to_csv("tesla_equity_2020.csv")

# %% [markdown]
# **Property, Plant & Equipment**

# %%
### set variables for years in reverse order year_1 being the latest
year_1 = st_of_profit_or_loss_df.columns[0]
year_2 = st_of_profit_or_loss_df.columns[1]
year_3 = st_of_profit_or_loss_df.columns[2]

### parsed list contains table, rows at list position 2-12
def fun(item):
    to_remove = ['', '$']
    if (item not in to_remove):
        return True
    else:
        return False
    
frames = []
for i in range(3,12):
    frames.append(pd.DataFrame([parse_table(reports_list[16]['url'])['data'][i]]))
ppe_df = pd.concat(frames)

### set titles of line items as index
ppe_df.index = ppe_df[ppe_df.columns[0]]
ppe_df = ppe_df.drop(0, axis=1)
ppe_df.index.name = 'Property, Plant & Eq, MLN USD'

### clean data
ppe_df = (ppe_df.replace('[\$, ]', '', regex=True)
          .replace('[(]', '-', regex=True)
          .replace('[)]', '', regex=True)
                               .replace('', 0, regex=True))

### convert values to float format
ppe_df = ppe_df.astype(float)

### drop columns with zero values
ppe_df = ppe_df.drop([1,2,4,5,6,8], axis=1)

### assign headings
ppe_df.columns = [year_1, year_2]

# %%
# //- // Company Specific code
#ppe_df.to_csv("tesla_ppe_2020.csv")

# %% [markdown]
# **Revenue by Geography**

# %%
### Revenue by geography

frames = []
for i in range(7):
    frames.append(pd.DataFrame([segment_revenues['data'][i][-3:]]))

segments_revenues_df = pd.concat(frames)

### clean data
segments_revenues_df = (segments_revenues_df.replace('[\$, ]', '', regex=True)
                        .replace('[(]', '-', regex=True)
                        .replace('[)]', '', regex=True)
                        .replace('', 0, regex=True))

### convert values to float
segments_revenues_df = segments_revenues_df.astype('float')

### drop columns with all 'zeros'
segments_revenues_df = segments_revenues_df.loc[(segments_revenues_df!=0).any(1)]


### assign headings
index_cols = []
for i in range(7):
    index_cols.append(segment_revenues['data'][i][0])
    
index_cols = list(dict.fromkeys(index_cols))

segments_revenues_df.index = index_cols
segments_revenues_df.index.name = 'Segment Revenue, MLN USD'
segments_revenues_df.columns = segment_revenues['headers'][1][-3:]

# %%
# //- // Company Specific code
#segments_revenues_df.to_csv("tesla_segments_2020.csv")
